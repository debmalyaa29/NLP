# %%
corpus=""" Hello Welcome ,to Dev Ka home.
Please do watch the entire course! to become expert in nlp
"""
print(corpus)
# Out:
#  Hello Welcome ,to Dev Ka home.
# Please do watch the entire course! to become expert in nlp

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk

print(nltk.data.path)
# Out:
# ['C:\\Users\\User/nltk_data', 'c:\\Users\\User\\anaconda3\\envs\\my-pytorch\\nltk_data', 'c:\\Users\\User\\anaconda3\\envs\\my-pytorch\\share\\nltk_data', 'c:\\Users\\User\\anaconda3\\envs\\my-pytorch\\lib\\nltk_data', 'C:\\Users\\User\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']

# %%
from nltk.tokenize import sent_tokenize
documents = sent_tokenize(corpus)
documents
# Out:
# [' Hello Welcome ,to Dev Ka home.',
#  'Please do watch the entire course!',
#  'to become expert in nlp']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello Welcome ,to Dev Ka home.
# Please do watch the entire course!
# to become expert in nlp

# %%
##paragraph -->words
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Dev',
#  'Ka',
#  'home',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'nlp']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Dev', 'Ka', 'home', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'nlp']

# %%
##if we want the punctuation is also treated as a separate word
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Dev',
#  'Ka',
#  'home',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'nlp']
